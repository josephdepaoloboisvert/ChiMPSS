# %%
from Docking import Docking
import MDAnalysis as mda
from MDAnalysis.analysis.rms import rmsd
from MDAnalysis.analysis import align
from rdkit import Chem
from rdkit.Chem import AllChem
import os, sys
sys.path.append('/home/exouser/Bridgeport/utils')
from bp_utils import analogue_alignment, return_max_common_substructure
# Out:
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/Bio/Application/__init__.py:40: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
analogue_name = 'LeuEnk'
rec_path = f'/home/exouser/MOR/docking/{analogue_name}/proteins/output/{analogue_name}_H.pdbqt'
lig_path = f'/home/exouser/MOR/docking/{analogue_name}/ligands/output/{analogue_name}.pdbqt'
config_dir = '/home/exouser/MOR/docking/config'
docking = Docking(rec_path, lig_path, config_dir)

# %%
docking.set_box(box_center=[0,0,6], box_dim=[15,15,15])

# %%
lig_out_dir = os.path.join(f'/home/exouser/MOR/docking/{analogue_name}/ligands/output/', 'docked_poses')
pdb_out_dir = docking.dock(lig_out_dir, n_poses=1, exhaustiveness=1)
# Out:
# Receptor LeuEnk_H
# Ligand LeuEnk
# AutoDock Vina 616d6c8-mod
# #################################################################
# # If you used AutoDock Vina in your work, please cite:          #
# #                                                               #
# # J. Eberhardt, D. Santos-Martins, A. F. Tillack, and S. Forli  #
# # AutoDock Vina 1.2.0: New Docking Methods, Expanded Force      #
# # Field, and Python Bindings, J. Chem. Inf. Model. (2021)       #
# # DOI 10.1021/acs.jcim.1c00203                                  #
# #                                                               #
# # O. Trott, A. J. Olson,                                        #
# # AutoDock Vina: improving the speed and accuracy of docking    #
# # with a new scoring function, efficient optimization and       #
# # multithreading, J. Comp. Chem. (2010)                         #
# # DOI 10.1002/jcc.21334                                         #
# ...

# %%
docking.compare(ref_pdb='/home/exouser/MOR/crystal_pdb/8f7r.pdb', 
                ref_lig_sele_str = 'chainid P', 
                ref_chainid = 'R')
# Out:
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: HD
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: OA
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: SA
# ...
