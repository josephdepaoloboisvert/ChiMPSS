# %% [markdown]
# #### Run some systems
#
# **CB2**
#  - AM630 - Testing System
#      -  Bridgeport - Provided by Anna - *josephdb/ChiMPSS/for_Jo/*
#      -  MotorRow - *josephdb/SimulationData/AM630_fg_MotorRow* **Complete**
#      -  FultonMarket (2.0x1.0 Default)\
#             Provided by anna in triplicate *iit122/josephdb/shared_data*
#      -  FultonMarket (3.5x7.0 HMR)\
#             Ran in triplicate (310-350 though) *josephdb/SimulationData/HMR_3.5_Runs/AM630_7ps_mpi* **Running**
#      -  Also ran (3.5x14.0 HMR) at other ladders for a short time...:\
#             300-360, 300-400, 310-400 K ***Running Longer**
#  - 9THC - Auto-Convergence Testing
#      -  Bridgeport - Provided by Anna - *josephdb/ChiMPSS/for_Jo/*
#      -  MotorRow - *josephdb/SimulationData/MotorRowRuns/CB2/9THC/* **Complete**
#      -  FultonMarket (2.0x1.0 Default AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/CB2_9THC_0/* **Submitted**
#      -  FultonMarket (2.0x1.0 HMR AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/CB2_9THC_HMR_0/* **Submitted**
#      -  FultonMarket (2.0x10.0 Default AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/9THC_0/* **ToDo**
#      -  FultonMarket (3.5x7.0 HMR AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/9THC_0/* **ToDo**
#      -  FultonMarket (3.5x14.0 HMR AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/9THC_0/* **ToDo**
#  - Bridgeport Results of Many Other systems provided by Anna
#
# **B2A**
#  - Isoprenaline
#        - 2.0x1.0 Default Triplicates provided by Talha
#  - Bridgeport Results of Many Other systems provided by Talha
#  - Retro Analyze the equilibration
#      -  FultonMarket (2.0x1.0 Default AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/IsoPrenaline_0/* **ToDo?**
#      -  FultonMarket (2.0x10.0 Default AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/IsoPrenaline_0/* **ToDo?**
#      -  FultonMarket (3.5x7.0 HMR AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/IsoPrenaline_0/* **ToDo?**
#      -  FultonMarket (3.5x14.0 HMR AutoConverge)\
#         *josephdb/SimulationData/Auto_Converge_2.0x1.0/IsoPrenaline_0/* **ToDo?**
# **5HT2A**
#  - Unknown Compound
#        - 2.0x1.0 Default Triplicates provided by Aiman
#  - *MotorRow* Results of Many Other systems provided by Aiman (Analogue pose info lost)
#
# **5HT2B**
#  - LSD
#        - Bridgeport for LSD with 5HT2B - Jetstream2
#        - MotorRow with restraints to each of the crystals - Jetstream2
#        - Default 2.0x1.0 AutoConverge
#            - 7srq **Submitted**
#            - 7srr **Submitted**
#            - 7srs **Submitted**
#
# **KOR**
#  - RS Sets at *iit122/josephdb/KOR_Luis/output/*  triplicates of RS1125 and 1126
#  - Julius Compounds

# %%
import os, sys, glob
from chimpss.motorrow import MotorRow

# %%
mr = MotorRow(pdb_file='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/Talha_Compounds/
              system_xml='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC_sys.xml',
              working_directory='/expanse/lustre/projects/uil133/josephdb/SimulationData/MotorRowRuns/9THC/')

# %%
mr = MotorRow(pdb_file='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC.pdb',
              system_xml='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC_sys.xml',
              working_directory='/expanse/lustre/projects/uil133/josephdb/SimulationData/MotorRowRuns/9THC/')

# %%
mr = MotorRow(pdb_file='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC.pdb',
              system_xml='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC_sys.xml',
              working_directory='/expanse/lustre/projects/uil133/josephdb/SimulationData/MotorRowRuns/9THC/')

# %%
mr = MotorRow(pdb_file='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC.pdb',
              system_xml='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC_sys.xml',
              working_directory='/expanse/lustre/projects/uil133/josephdb/SimulationData/MotorRowRuns/9THC/')

# %%
mr = MotorRow(pdb_file='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC.pdb',
              system_xml='/expanse/lustre/projects/uil133/josephdb/ChiMPSS/for_Jo/9THC_sys.xml',
              working_directory='/expanse/lustre/projects/uil133/josephdb/SimulationData/MotorRowRuns/9THC/')

# %%
import os

input_pdb='/expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0.pdb'
input_system='/expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0_sys.xml'
input_state='/expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0_state.xml'
output_dir='/expanse/lustre/projects/uil133/josephdb/SimulationData/FultonMarket_Test3.5_4Julius/'

T_min, T_max = 300, 450
n_replicates = 100

import os
if not os.path.isdir(output_dir):
    os.makedirs(output_dir, exist_ok=True)

# %%
from chimpss.fultonmarket import FultonMarket as FM
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
#
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************
# jax:    0.7.2
# jaxlib: 0.7.2
# numpy:  2.3.5
# python: 3.12.7 | packaged by conda-forge | (main, Oct  4 2024, 16:05:46) [GCC 13.3.0]
# ...

# %%
market = FM(input_pdb=input_pdb,
            input_system=input_system,
            input_state=input_state, 
            T_min=T_min, T_max=T_max, n_replicates=n_replicates, sele_str=None)
# Out:
# 03/24/2026 13:39:24//Welcome to FultonMarket.
# 03/24/2026 13:39:25//Found input_pdb: /expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0.pdb
# 03/24/2026 13:39:27//Found input_system: /expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0_sys.xml
# 03/24/2026 13:39:27//Found input_state: /expanse/lustre/projects/iit122/josephdb/shared_data/filesforjoe/0_state.xml

# %%
market.run(iter_length=0.014,
           dt=3.5, sim_length=5.6,
           convergence_thresh=None, resSeqs=None,
           total_sim_time=56,
           output_dir=output_dir)
# Out:
# 03/24/2026 13:39:27//Found total simulation time of 56 nanoseconds
# 03/24/2026 13:39:27//Found iteration length of 0.014 nanoseconds
# 03/24/2026 13:39:27//Found timestep of 3.5 femtoseconds
# 03/24/2026 13:39:27//Found length of simulation to be 5.6 nanoseconds
# 03/24/2026 13:39:27//Found number of replicates 100
# 03/24/2026 13:39:27//Found initial acceptance rate threshold 0.5
# 03/24/2026 13:39:27//Found terminal acceptance rate threshold 0.35
# 03/24/2026 13:39:27//Found output_dir /expanse/lustre/projects/uil133/josephdb/SimulationData/FultonMarket_Test3.5_4Julius/
# ...

# %%
raise Exception("STOPSTOPSTOSPTOSPTOSPTSTPOSPTSOTSPTSPOT")

# %% [markdown]
# #### Validate with Bare Bones Code

# %%
from openmm import XmlSerializer, LangevinIntegrator
from openmm.app import PDBFile, Simulation, StateDataReporter, DCDReporter

with open(input_system, 'r') as f:
    system = XmlSerializer.deserialize(f.read())
pdb = PDBFile(input_pdb)
topology = pdb.topology

sim = Simulation(topology, system,
                 LangevinIntegrator(300, 1.0, 0.002),
                 state=input_state)

state = sim.context.getState(positions=True, velocities=True)
positions = state.getPositions()
velocities = state.getVelocities()
box_vectors = state.getPeriodicBoxVectors()

sim.reporters.append(StateDataReporter('test.stdout', 1, potentialEnergy=True,kineticEnergy=True,totalEnergy=True,temperature=True,volume=True))

# %%
#After loading the simulation, try 1000 2 fs steps of Langevin at 300K, to ensure stability.
i = 0
try:
    for i in range(1000):
        sim.step(1)
    print("Stable")
except:
    print(i)

# %%
from openmm import MonteCarloMembraneBarostat
from openmm import unit

P = 1.0 * unit.bar
# system.addForce(MonteCarloMembraneBarostat(P, 300*unit.bar*unit.nanometer, T_min*unit.kelvin,
#                                            MonteCarloMembraneBarostat.XYIsotropic,
#                                            MonteCarloMembraneBarostat.ZFree, 100))

# %%
from openmmtools.multistate import ParallelTemperingSampler

# %%
from openmmtools.states import ThermodynamicState, SamplerState



reference_thermo_state = ThermodynamicState(system=system,
                                            temperature=T_min*unit.kelvin,
                                            pressure=1*unit.bar)

reference_sampler_state = SamplerState(positions=positions,
                                       velocities=velocities,
                                       box_vectors=box_vectors)

# %%
#Target 30% acceptance?
temperature_ladder = lambda T_min, T_max, n_reps, rep_ind: T_min*(((T_max/T_min)**(1/(n_reps - 1)))**rep_ind)
temperatures = [unit.kelvin*round(temperature_ladder(T_min=T_min, T_max=T_max, n_reps=n_replicates, rep_ind=rep_ind), 3) for rep_ind in range(n_replicates)]

# %%
n_steps_per_iteration = 100

# %%
from openmmtools import mcmc
timestep = 3.5*unit.femtosecond

#integrator1 = BetterMTSLangevin(T_min, friction=1.0, dt=2*timestep.value_in_unit(unit.picosecond), groups=[(0,2),(1,1)])
integrator2 = openmmtools.integrators.MTSIntegrator(timestep=2*timestep, groups=[(0,2),(1,1)])

# %%
moves = {'LDMove': mcmc.LangevinDynamicsMove(timestep=timestep, n_steps=n_steps_per_iteration),
         'LSDMove': mcmc.LangevinSplittingDynamicsMove(timestep=timestep, n_steps=n_steps_per_iteration),
         'MTSMove': mcmc.IntegratorMove(integrator=integrator2, n_steps=n_steps_per_iteration)}

# %%
import mdtraj as md
traj = md.load(input_pdb)

# %%
indices = traj.top.select('protein or resname UNK')

# %%
from openmmtools.multistate import ParallelTemperingSampler, MultiStateReporter
import os

move_name = 'LDMove'
move = moves[move_name]

storage_file = f"integrator_{move_name}_HMR_testing.nc"
if os.path.isfile(storage_file):
    os.remove(storage_file)

reporter = MultiStateReporter(storage=storage_file,
                              checkpoint_interval=50,  # iterations between checkpoints
                              analysis_particle_indices=indices) # A subset, to save disk

n_iterations = 100

sampler = ParallelTemperingSampler(mcmc_moves=move,
                                   number_of_iterations=n_iterations,
                                   replica_mixing_scheme='swap-all')

# %%
sampler.create(thermodynamic_state = reference_thermo_state,
               sampler_states = reference_sampler_state,
               storage=reporter, temperatures=temperatures, n_temperatures=n_replicates)

# %%
from datetime import datetime
start = datetime.now()
sampler.run()
print(f"completed in: {datetime.now() - start}")

# %%
print(f"completed in: {datetime.now() - start}")

# %%
raise Exception('S T O P')

# %% [markdown]
# #### Something

# %%
market.temperatures[0].__float__

# %%
input_dir = '/media/volume/Large-Storage/kor/Luis_RS_cmpds/'
name = 'RS1125'
output_dir = '/media/volume/Large-Storage/kor/RS1125_output/'
replicate = '0'

total_sim_time = 20
sub_sim_length = 2
iter_length = 0.005

# %%
# Inputs
import os
input_sys = os.path.join(input_dir, name+'_sys.xml')
input_state = os.path.join(input_dir, name+'_state.xml')
input_pdb = os.path.join(input_dir, name+'.pdb')
output_dir = os.path.join(output_dir, name + '_' + str(replicate))
if not os.path.exists(output_dir):
    os.makedirs(output_dir, exist_ok=True)
assert os.path.exists(output_dir)

# %% [markdown]
# #### NOT THIS
# ```
# #Try the easiest thing first, load the system and double the masses
# mass_scale = 2
#
#
# from openmm import *
# from openmm.app import *
# from openmm.unit import *
#
# with open(input_sys, 'r') as f:
#     system = XmlSerializer.deserialize(f.read())
#
# unique_masses = []
# for i in range(system.getNumParticles()):
#     mass = system.getParticleMass(i)
#     if mass < 1.1*dalton:
#         system.setParticleMass(i, mass_scale*mass)
#
# with open(os.path.join(input_dir, name+'_sys_D.xml'), 'w') as f:
#     f.write(XmlSerializer.serialize(system))
#
# input_sys = os.path.join(input_dir, name+'_sys_D.xml')
# ```

# %% [markdown]
# ### Perform Hydrogen Mass Augmentation by 'Stealing' from the Bonded Heavy Atom (up to 4 Dalton total H mass)

# %%
from openmm import *
from openmm.app import *
from openmm.unit import *
import numpy as np


pdb = PDBFile(input_pdb)
with open(input_sys, 'r') as f:
    normal_sys = XmlSerializer.deserialize(f.read())
top = pdb.topology
top.getNumBonds()

# %%
for i in np.linspace(1, 3.5, 40):
    print('#################################################################################################################')
    print(f'#################################{i=}##########################################################')
    print('#################################################################################################################')

    sys = deepcopy(normal_sys)
    
    delta_H = i*element.hydrogen.mass
    
    print('Expect Masses')
    for el in [element.hydrogen, element.carbon, element.nitrogen, element.oxygen]:
        if el == element.hydrogen:
            print(el, el.mass + delta_H)
        else:
            print(el, '1H', el.mass - delta_H, '2H', el.mass - 2*delta_H, '3H', el.mass - 3*delta_H)
    
    h = element.hydrogen
    h_bonds = [] #haha it is but it isn't you know?
    
    for bond in top.bonds():
        is_h = [h == atom.element for atom in [bond.atom1, bond.atom2]]
        if True in is_h: #Assume that there is at most one hydrogen per bond, thus only one element is ever true
            #Obtain Atoms
            h_atom = [bond.atom1, bond.atom2][is_h.index(True)]
            heavy_atom = [bond.atom1, bond.atom2][is_h.index(False)]
            #Indices
            h_ind = h_atom.index
            heavy_ind = heavy_atom.index
            #Masses
            
            h_mass = sys.getParticleMass(h_ind)
            heavy_mass = sys.getParticleMass(heavy_ind)
            #New Mass
            new_h_mass = h_mass + delta_H
            new_heavy_mass = heavy_mass - delta_H
            #Record new masses
            _ = sys.setParticleMass(h_ind, new_h_mass)
            _ = sys.setParticleMass(heavy_ind, new_heavy_mass)
    
    #Get some random atoms
    #print(sys.getParticleMass(420), sys.getParticleMass(69), sys.getParticleMass(649), sys.getParticleMass(469), sys.getParticleMass(690))
    
    
    input_sys = os.path.join(input_dir, name+'_sys_T.xml')
    with open(input_sys, 'w') as f:
        f.write(XmlSerializer.serialize(sys))
    
    
    # Run rep exchange
    market = FM(input_pdb=input_pdb, 
                input_system=input_sys, 
                input_state=input_state, 
                T_min=300, T_max=310,
                n_replicates=20,
                sele_str=None)
    
    
    # try:
    market.run(iter_length=iter_length,
               dt=3.0,
               sim_length=sub_sim_length,
               convergence_thresh=None,
               resSeqs=None,
               total_sim_time=total_sim_time,
               output_dir=output_dir)
    #     print('#################################################################################################################')
    #     print(f'#####################SUCCESS!############{i=}##########################################################')
    #     print('#################################################################################################################')
    # except:
    #     print('#################################################################################################################')
    #     print(f'#####################FAILURE!############{i=}##########################################################')
    #     print('#################################################################################################################')
